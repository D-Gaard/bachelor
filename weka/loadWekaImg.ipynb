# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
p = "Classified_image0005.tif"
a = cv2.imread(p,0)

a.shape
a.min()
# Out:
# 76

# %%
a = np.where(a == 76,255,0)

# %%
plt.imshow(a,cmap="gray")
plt.show()
